# %% [markdown]
# Chapter 4. Linear Algebra
# ---
#
# - Mental notes:
#     - How is linear algebra useful when working with data?
#     - How is linear algebra used in machine learning?
#     - How can I apply machine learning to any current project?
#     - What is a vector?
#     - What is the dot product?
#     - What are Eigenvectors and Eigenvalues, and what is their use?
#     - What is the Covariance Matrix?
#     - What is Principal Component Analysis?

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Sample data: 10 samples with 2 features
X = np.array([
    [2.5, 2.4],
    [0.5, 0.7],
    [2.2, 2.9],
    [1.9, 2.2],
    [3.1, 3.0],
    [2.3, 2.7],
    [2.0, 1.6],
    [1.0, 1.1],
    [1.5, 1.6],
    [1.1, 0.9]
])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
print(X_scaled)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c='blue', marker='o')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Sample Dataset')
plt.grid()
plt.show()
# Out:
# [[ 0.92627881  0.61016865]
#  [-1.7585873  -1.506743  ]
#  [ 0.52354889  1.23278973]
#  [ 0.12081898  0.36112022]
#  [ 1.73173864  1.35731394]
#  [ 0.6577922   0.9837413 ]
#  [ 0.25506228 -0.38602507]
#  [-1.08737078 -1.00864614]
#  [-0.41615425 -0.38602507]
#  [-0.95312747 -1.25769457]]
