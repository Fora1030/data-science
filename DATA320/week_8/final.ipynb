# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
student_data = pd.read_excel("Student survey.xlsx", sheet_name='Student survey')

# %%
student_data
# Out:
#     Student_ID  Years_in_School Full_Part_Time Success_Coach  \
# 0            1                6      Full-time        Olivia
# 1            2                3      Part-time       Diamond
# 2            3                4      Part-time          Alex
# 3            4                6      Part-time       Diamond
# 4            5                2      Part-time         Mateo
# ..         ...              ...            ...           ...
# 95          96                5      Part-time         Mateo
# 96          97                1      Part-time        Gianna
# 97          98                3      Part-time        Olivia
# 98          99                5      Full-time        Olivia
# 99         100                4      Full-time       Diamond
#
#         Degree_Sought Attend_Study_Session  Total_Minutes_Spent  Age  \
# 0    Bachelors Degree                   No                  275   18
# 1   Associates degree                   No                  205   36
# ...

# %%
sns.histplot(student_data['Grade'])
# Out:
# <Axes: xlabel='Grade', ylabel='Count'>

# %%
sns.histplot(student_data['Years_in_School'])
# Out:
# <Axes: xlabel='Years_in_School', ylabel='Count'>

# %%
sns.histplot(student_data['Full_Part_Time'])
# Out:
# <Axes: xlabel='Full_Part_Time', ylabel='Count'>

# %%
# sns.boxplot(student_data["Total_Minutes_Spent"])
sns.histplot(student_data["Total_Minutes_Spent"])
# Out:
# <Axes: xlabel='Total_Minutes_Spent', ylabel='Count'>

# %%
sns.countplot(student_data['Success_Coach'])
# Out:
# <Axes: xlabel='count', ylabel='Success_Coach'>

# %%
sns.countplot(student_data['Degree_Sought'])
# Out:
# <Axes: xlabel='count', ylabel='Degree_Sought'>

# %%
sns.countplot(student_data['Previous_Education'])
# Out:
# <Axes: xlabel='count', ylabel='Previous_Education'>

# %%
sns.countplot(student_data['First_Gen'])
# Out:
# <Axes: xlabel='count', ylabel='First_Gen'>

# %%
sns.countplot(student_data['Financial_Aid'])
# Out:
# <Axes: xlabel='count', ylabel='Financial_Aid'>

# %%
student_data.describe()
# Out:
#        Student_ID  Years_in_School  Total_Minutes_Spent         Age  \
# count  100.000000       100.000000           100.000000  100.000000
# mean    50.500000         3.600000           166.200000   28.530000
# std     29.011492         2.146173            77.330982    5.990658
# min      1.000000         0.000000            30.000000   18.000000
# 25%     25.750000         2.000000            98.000000   24.000000
# 50%     50.500000         3.000000           171.500000   29.000000
# 75%     75.250000         5.000000           222.000000   34.000000
# max    100.000000         7.000000           298.000000   39.000000
#
#               GPA  Work_Hours  Commute_Time  Extra_Curricular       Grade
# count  100.000000  100.000000    100.000000        100.000000  100.000000
# mean     3.020400   19.410000     58.540000          2.080000   87.601911
# std      0.559939   11.467208     32.776692          1.440258   13.871393
# ...

# %%
sns.histplot(student_data['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.scatterplot(student_data, y="Grade",x="Total_Minutes_Spent",hue='Major')
# Out:
# <Axes: xlabel='Total_Minutes_Spent', ylabel='Grade'>

# %%
sns.histplot(student_data["Grade"])
# Out:
# <Axes: xlabel='Grade', ylabel='Count'>
